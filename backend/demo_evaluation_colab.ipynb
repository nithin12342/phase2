# %% [markdown]
# #  H5-OmniFusion Demo Sample Evaluator
# **Objective:** Run the full 	est_full.py 303 inference pipeline accurately by loading the 	ransformers models (mental-roberta-base, wav2vec2-large-xlsr-53) locally on a free Colab T4 GPU, circumventing the HuggingFace API Deprecations without crashing a local laptop.
#
# ###  Step 1: Clone Repository and Install Dependencies

# %%
import os

# Clone the user's latest GitHub repository containing the updated hf_client.py
# REPLACE https://github.com/nithin12342/phase2.git with the actual repository URL once pushed.
# !git clone https://github.com/nithin12342/phase2.git /content/phase2

# Install required dependencies
# %cd /content/phase2/backend
# !pip install -r requirements.txt
# !pip install librosa transformers torch uvicorn[standard] python-multipart

# %% [markdown]
# ###  Step 2: (Optional) Mount Google Drive
# If the H5-OmniFusion checkpoint model file (omnifusion_model.pt) is not inside your git repository because of GitHub file size limits, you must mount Google Drive to link it.

# %%
from google.colab import drive
drive.mount('/content/drive')

# Symlink the model if it resides in Google Drive instead of the cloned git repo.
# Example:
# !ln -s /content/drive/MyDrive/YOUR_MODEL_PATH/omnifusion_model.pt /content/phase2/ml_pipeline/...

# %% [markdown]
# ###  Step 3: Run Full Inference Pipeline on Demo Sample
# Evaluate PID 303 (Not Depressed) using the correct [CLS] text pooling and mean() audio pooling configurations directly loaded on the Colab GPU.

# %%
# %cd /content/phase2/backend

# Execute the local inference pipeline
# !python test_full.py 303
